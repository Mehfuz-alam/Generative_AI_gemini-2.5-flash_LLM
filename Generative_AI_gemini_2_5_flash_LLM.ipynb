# %% [markdown]
# <a href="https://colab.research.google.com/github/Mehfuz-alam/Generative_AI_gemini-2.5-flash_LLM/blob/main/Generative_AI_gemini_2_5_flash_LLM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Large Language Models (LLMs) Reference
#
# ## Open-Source Models
# GPT-J
#
# EleutherAI/gpt-j-6B
# BLOOM
#
# BigScience/bloom
# OPT
#
# Facebook AI Research (FAIR)
# T5
#
# Google/T5
# BERT
#
# Google/BERT
# RoBERTa
#
# Facebook AI/RoBERTa
# LLaMA
#
# Facebook AI Research (FAIR)
#
#
# ## Paid/Commercial Models
# GPT-3
#
# OpenAI
# GPT-4
#
# OpenAI
# Claude
#
# Anthropic
# PaLM and Gemini
#
# Google AI
# Jurassic-1
#
# AI21 Labs
# ERNIE
#
# Baidu
#
# LaMDA
#
# Google AI
# Cohere
#
# Cohere
#
#
#
# ## Some useful links
# Google Gemini API Key :
# https://aistudio.google.com/api-keys
#
# Anthrophic API Key : https://www.anthropic.com/api
#
# Open AI API Key : https://openai.com/index/openai-api/
#
# Gemeni docs links
# https://ai.google.dev/gemini-api/docs/quickstart?lang=python
#
# Open source LLM
# https://ollama.com/

# %%
# !pip install google-generativeai

# %%
import getpass

API_KEY = getpass.getpass("Enter your Gemini API key: ")
print("API key loaded safely!")
# Out:
# Enter your Gemini API key: ··········
# API key loaded safely!

# %%
import google.generativeai as genai

# %%
genai.configure(api_key=API_KEY)

# %%
model = genai.GenerativeModel('gemini-2.5-flash')

# %%
response = model.generate_content("Write a Python two add two numbers")

# %%
print(response.text)
# Out:
# You want to write a Python script to add two numbers. There are several ways to do this, ranging from the very basic with hardcoded values to more robust solutions that take user input and handle potential errors.
#
# Here are a few common ways:
#
# ---
#
# ### 1. Simple: Hardcoded Numbers
#
# This is the most basic way, where you define the numbers directly in your code.
#
# ```python
# # Define the two numbers
# num1 = 5
# num2 = 3
#
# # Add them
# sum_result = num1 + num2
#
# # Print the result
# print(f"The sum of {num1} and {num2} is: {sum_result}")
# ```
#
# **Output:**
# ```
# The sum of 5 and 3 is: 8
# ```
#
# ---
#
# ### 2. Getting Input from the User (Most Common)
#
# This version allows the user to enter the numbers when the script runs.
#
# ...
